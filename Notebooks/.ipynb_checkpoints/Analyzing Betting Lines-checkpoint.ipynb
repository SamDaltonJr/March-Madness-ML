# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os, glob

path = '../input/betting-lines/'

all_betting = glob.glob(os.path.join(path, '*.xlsx'))


all_df = []

for f in all_betting:
    df = pd.read_excel(f)
    df['Season'] = '20'+ f[-7:-5]
    all_df.append(df)
    
merged_df = pd.concat(all_df,ignore_index=True, sort=True)

merged_df = merged_df.drop(['1st','2nd','Open','2H'],axis=1)

merged_df
# Out:
#        Close  Date  Final      ML  Rot Season              Team VH
# 0      127.5  1105   42.0     200  503   2008             Maine  N
# 1        5.5  1105   44.0    -240  504   2008          Richmond  N
# 2        144  1105   71.0   13000  505   2008        TennMartin  V
# 3       35.5  1105  102.0  -39000  506   2008          MemphisU  H
# 4          3  1106   69.0    -160  721   2008       GardnerWebb  N
# 5      139.5  1106   55.0     140  722   2008        AlabamaA&M  N
# 6        134  1106   40.0    3000  723   2008   CentralArkansas  V
# 7       26.5  1106   67.0   -7000  724   2008          Kentucky  H
# 8        128  1106   62.0     105  725   2008             Maine  N
# 9        1.5  1106   66.0    -125  726   2008        TennMartin  N
# 10     140.5  1106   63.0    4000  727   2008          Richmond  V
# 11      29.5  1106   80.0  -10000  728   2008          MemphisU  H
# 12       166  1107   82.0    3000  519   2008        OhioValley  N
# 13        25  1107   89.0   -7000  520   2008           Buffalo  N
# 14     138.5  1107   65.0      NL  521   2008       MorganState  V
# 15        26  1107   69.0      NL  522   2008       Connecticut  H
# 16       129  1107   59.0     140  523   2008        AlabamaA&M  N
# 17       3.5  1107   69.0    -160  524   2008   CentralArkansas  N
# 18     132.5  1107   84.0    3000  525   2008       GardnerWebb  V
# 19      26.5  1107   68.0   -7000  526   2008          Kentucky  H
# 20       163  1108   66.0     600  707   2008        OhioValley  N
# 21      11.5  1108   77.0    -900  708   2008       MorganState  N
# 22       143  1108   57.0    1500  709   2008           Buffalo  V
# 23        19  1108   82.0   -3000  710   2008       Connecticut  H
# 24     133.5  1108   75.0     325  711   2008  ECentralOklahoma  N
# 25       8.5  1108   76.0    -400  712   2008           DenverU  N
# 26       131  1108   55.0    1420  713   2008      SanFrancisco  V
# 27      17.5  1108   71.0   -2600  714   2008          Oklahoma  H
# 28     151.5  1109   72.0     158  527   2008    NewMexicoState  V
# 29       3.5  1109   80.0    -180  528   2008              Ohio  H
# ...      ...   ...    ...     ...  ...    ...               ... ..
# 95700    140   330   75.0     211  683   2019         TexasTech  N
# 95701      5   330   69.0    -255  684   2019           Gonzaga  N
# 95702    149   331   68.0     135  691   2019     MichiganState  N
# 95703    2.5   331   67.0    -155  692   2019              Duke  N
# 95704  142.5   331   77.0     180  693   2019            Auburn  N
# 95705    4.5   331   71.0    -220  694   2019          Kentucky  N
# 95706  151.5   401   61.0     105  701   2019            Depaul  V
# 95707      1   401   63.0    -125  702   2019      SouthFlorida  H
# 95708    150   402   64.0     100  709   2019      WichitaState  N
# 95709      1   402   71.0    -120  710   2019          Lipscomb  N
# 95710  137.5   402   58.0    -110  711   2019             Texas  N
# 95711     pk   402   44.0    -110  712   2019               TCU  N
# 95712    173   402   78.0     240  723   2019           Hampton  V
# 95713      7   402   80.0    -300  724   2019          Marshall  H
# 95714  173.5   402   86.0     210  725   2019     TexasSouthern  V
# 95715      6   402   87.0    -260  726   2019      WiscGreenBay  H
# 95716  144.5   403   96.0     190  717   2019      SouthFlorida  V
# 95717    4.5   403  100.0    -240  718   2019            Depaul  H
# 95718  142.5   404   66.0     105   27   2019          Lipscomb  N
# 95719    1.5   404   81.0    -125  728   2019             Texas  N
# 95720    169   404   70.0     185  733   2019      WiscGreenBay  V
# 95721      5   404   90.0    -230  734   2019          Marshall  H
# 95722  146.5   405   77.0     105  735   2019      SouthFlorida  V
# 95723    1.5   405   65.0    -125  736   2019            Depaul  H
# 95724  133.5   406   61.0     120  801   2019         TexasTech  V
# 95725      2   406   51.0    -140  802   2019     MichiganState  H
# 95726    132   406   62.0     260  803   2019            Auburn  V
# 95727    6.5   406   63.0    -330  804   2019          Virginia  H
# 95728  119.5   408   77.0     116  811   2019         TexasTech  V
# 95729      2   408   85.0    -136  812   2019          Virginia  H
#
# [95730 rows x 8 columns]

# %%
index = 0
new_df = []
while index<len(merged_df.index):
    i=index
    new_row = merged_df.iloc[[i,i+1]]
    index+=2
    if new_row.Final[i]>new_row.Final[i+1]:
        winner=new_row.Team[i]
    else:
        winner=new_row.Team[i+1]
    try:
        float(new_row.Close[i])
    except ValueError:
        continue
    try:
        float(new_row.ML[i])
    except ValueError:
        continue
    if new_row.Close[i]>100.0:
        line=new_row.Close[i+1]
        favorite=new_row.Team[i+1]
        underdog_score = new_row.Final[i]
        favorite_score = new_row.Final[i+1]
    else:
        line=new_row.Close[i]
        favorite=new_row.Team[i]
        underdog_score = new_row.Final[i+1]
        favorite_score = new_row.Final[i]
    if float(new_row.ML[i])>0:
        ML=new_row.ML[i+1]
    else:
        ML=new_row.ML[i]
    MoV = favorite_score - underdog_score
    new_df.append({'Season':new_row.Season[i],'Team1':new_row.Team[i], 'Team2':new_row.Team[i+1],'Favorite':favorite,'Line':line,'Winner':winner,'ML':ML,'MoV':MoV})
    
    
df1 = pd.DataFrame(new_df)

# %%
df1 = df1[['Season','Team1','Team2','Line','ML','Favorite','Winner','MoV']]

# %%
from copy import deepcopy

indexNames = df1[df1['Winner']==df1['Favorite']].index

df1 = df1.assign(Result=0)

df1.loc[indexNames,'Result'] = 1

df1
# Out:
#       Season             Team1            Team2  Line      ML  \
# 0       2008             Maine         Richmond   5.5    -240
# 1       2008        TennMartin         MemphisU  35.5  -39000
# 2       2008       GardnerWebb       AlabamaA&M     3    -160
# 3       2008   CentralArkansas         Kentucky  26.5   -7000
# 4       2008             Maine       TennMartin   1.5    -125
# 5       2008          Richmond         MemphisU  29.5  -10000
# 6       2008        OhioValley          Buffalo    25   -7000
# 7       2008        AlabamaA&M  CentralArkansas   3.5    -160
# 8       2008       GardnerWebb         Kentucky  26.5   -7000
# 9       2008        OhioValley      MorganState  11.5    -900
# 10      2008           Buffalo      Connecticut    19   -3000
# 11      2008  ECentralOklahoma          DenverU   8.5    -400
# 12      2008      SanFrancisco         Oklahoma  17.5   -2600
# 13      2008    NewMexicoState             Ohio   3.5    -180
# 14      2008           Fordham         Columbia     5    -230
# 15      2008            Drexel     Pennsylvania     3    -150
# 16      2008            Butler        BallState  10.5    -620
# 17      2008       FlaAtlantic      RhodeIsland    13   -1300
# 18      2008    ClevelandState     SouthFlorida   7.5    -340
# 19      2008             Brown  EasternMichigan   5.5    -235
# 20      2008            Temple        Tennessee  17.5   -2200
# 21      2008            Depaul        Creighton     3    -155
# 22      2008              Troy          Alabama    17   -2000
# 23      2008         NewMexico         Colorado     1    -120
# 24      2008            Auburn           Tulane   2.5    -145
# 25      2008   LoyolaMarymount        CalIrvine   9.5    -500
# 26      2008          SanDiego           Hawaii   8.5    -415
# 27      2008     Massachusetts       CalPolySLO   5.5    -240
# 28      2008        NoIllinois     NorthernIowa    14   -1250
# 29      2008   WesternCarolina     BowlingGreen     1    -125
# ...      ...               ...              ...   ...     ...
# 44706   2019          Colorado            Texas     5    -220
# 44707   2019   CoastalCarolina           Depaul     8    -350
# 44708   2019            Purdue        Tennessee   1.5    -130
# 44709   2019            Oregon         Virginia   8.5    -440
# 44710   2019      FloridaState          Gonzaga   7.5    -425
# 44711   2019         TexasTech         Michigan     2    -140
# 44712   2019   LoyolaMarymount     SouthFlorida     4    -190
# 44713   2019           Hampton             NJIT   3.5    -170
# 44714   2019     TexasSouthern         ULMonroe     8    -400
# 44715   2019               LSU    MichiganState     6    -280
# 44716   2019      VirginiaTech             Duke   7.5    -450
# 44717   2019          HoustonU         Kentucky     2    -135
# 44718   2019            Auburn    NorthCarolina   5.5    -270
# 44719   2019     CSBakersfield     WiscGreenBay     6    -270
# 44720   2019            Purdue         Virginia   4.5    -225
# 44721   2019         TexasTech          Gonzaga     5    -255
# 44722   2019     MichiganState             Duke   2.5    -155
# 44723   2019            Auburn         Kentucky   4.5    -220
# 44724   2019            Depaul     SouthFlorida     1    -125
# 44725   2019      WichitaState         Lipscomb     1    -120
# 44726   2019             Texas              TCU    pk    -110
# 44727   2019           Hampton         Marshall     7    -300
# 44728   2019     TexasSouthern     WiscGreenBay     6    -260
# 44729   2019      SouthFlorida           Depaul   4.5    -240
# 44730   2019          Lipscomb            Texas   1.5    -125
# 44731   2019      WiscGreenBay         Marshall     5    -230
# 44732   2019      SouthFlorida           Depaul   1.5    -125
# 44733   2019         TexasTech    MichiganState     2    -140
# 44734   2019            Auburn         Virginia   6.5    -330
# 44735   2019         TexasTech         Virginia     2    -136
#
#               Favorite           Winner   MoV  Result
# 0             Richmond         Richmond   2.0       1
# 1             MemphisU         MemphisU  31.0       1
# 2          GardnerWebb      GardnerWebb  14.0       1
# 3             Kentucky         Kentucky  27.0       1
# 4           TennMartin       TennMartin   4.0       1
# 5             MemphisU         MemphisU  17.0       1
# 6              Buffalo          Buffalo   7.0       1
# 7      CentralArkansas  CentralArkansas  10.0       1
# 8             Kentucky      GardnerWebb -16.0       0
# 9          MorganState      MorganState  11.0       1
# 10         Connecticut      Connecticut  25.0       1
# 11             DenverU          DenverU   1.0       1
# 12            Oklahoma         Oklahoma  16.0       1
# 13                Ohio             Ohio   8.0       1
# 14             Fordham          Fordham  18.0       1
# 15              Drexel           Drexel   8.0       1
# 16              Butler           Butler  16.0       1
# 17         RhodeIsland      RhodeIsland  27.0       1
# 18        SouthFlorida   ClevelandState  -3.0       0
# 19     EasternMichigan            Brown -19.0       0
# 20           Tennessee        Tennessee  17.0       1
# 21           Creighton        Creighton  12.0       1
# 22             Alabama          Alabama  12.0       1
# 23           NewMexico        NewMexico   7.0       1
# 24              Tulane           Tulane  15.0       1
# 25           CalIrvine        CalIrvine  13.0       1
# 26              Hawaii         SanDiego  -1.0       0
# 27       Massachusetts    Massachusetts  26.0       1
# 28        NorthernIowa     NorthernIowa  30.0       1
# 29     WesternCarolina  WesternCarolina   3.0       1
# ...                ...              ...   ...     ...
# 44706            Texas            Texas  13.0       1
# 44707           Depaul           Depaul   5.0       1
# 44708        Tennessee           Purdue  -5.0       0
# 44709         Virginia         Virginia   4.0       1
# 44710          Gonzaga          Gonzaga  14.0       1
# 44711         Michigan        TexasTech -19.0       0
# 44712     SouthFlorida     SouthFlorida   9.0       1
# 44713             NJIT          Hampton -12.0       0
# 44714         ULMonroe    TexasSouthern  -6.0       0
# 44715    MichiganState    MichiganState  17.0       1
# 44716             Duke             Duke   2.0       1
# 44717         Kentucky         Kentucky   4.0       1
# 44718    NorthCarolina           Auburn -17.0       0
# 44719     WiscGreenBay     WiscGreenBay  15.0       1
# 44720         Virginia         Virginia   5.0       1
# 44721          Gonzaga        TexasTech  -6.0       0
# 44722             Duke    MichiganState  -1.0       0
# 44723         Kentucky           Auburn  -6.0       0
# 44724     SouthFlorida     SouthFlorida   2.0       1
# 44725         Lipscomb         Lipscomb   7.0       1
# 44726              TCU            Texas -14.0       0
# 44727         Marshall         Marshall   2.0       1
# 44728     WiscGreenBay     WiscGreenBay   1.0       1
# 44729           Depaul           Depaul   4.0       1
# 44730            Texas            Texas  15.0       1
# 44731         Marshall         Marshall  20.0       1
# 44732           Depaul     SouthFlorida -12.0       0
# 44733    MichiganState        TexasTech -10.0       0
# 44734         Virginia         Virginia   1.0       1
# 44735         Virginia         Virginia   8.0       1
#
# [44736 rows x 9 columns]

# %%
#Drop all games where the line is 0 because there's no favorite
indexNames = df1[df1['Line']=='pk'].index
df1.drop(indexNames,inplace=True)

df1
# Out:
#       Season             Team1            Team2  Line      ML  \
# 0       2008             Maine         Richmond   5.5    -240
# 1       2008        TennMartin         MemphisU  35.5  -39000
# 2       2008       GardnerWebb       AlabamaA&M     3    -160
# 3       2008   CentralArkansas         Kentucky  26.5   -7000
# 4       2008             Maine       TennMartin   1.5    -125
# 5       2008          Richmond         MemphisU  29.5  -10000
# 6       2008        OhioValley          Buffalo    25   -7000
# 7       2008        AlabamaA&M  CentralArkansas   3.5    -160
# 8       2008       GardnerWebb         Kentucky  26.5   -7000
# 9       2008        OhioValley      MorganState  11.5    -900
# 10      2008           Buffalo      Connecticut    19   -3000
# 11      2008  ECentralOklahoma          DenverU   8.5    -400
# 12      2008      SanFrancisco         Oklahoma  17.5   -2600
# 13      2008    NewMexicoState             Ohio   3.5    -180
# 14      2008           Fordham         Columbia     5    -230
# 15      2008            Drexel     Pennsylvania     3    -150
# 16      2008            Butler        BallState  10.5    -620
# 17      2008       FlaAtlantic      RhodeIsland    13   -1300
# 18      2008    ClevelandState     SouthFlorida   7.5    -340
# 19      2008             Brown  EasternMichigan   5.5    -235
# 20      2008            Temple        Tennessee  17.5   -2200
# 21      2008            Depaul        Creighton     3    -155
# 22      2008              Troy          Alabama    17   -2000
# 23      2008         NewMexico         Colorado     1    -120
# 24      2008            Auburn           Tulane   2.5    -145
# 25      2008   LoyolaMarymount        CalIrvine   9.5    -500
# 26      2008          SanDiego           Hawaii   8.5    -415
# 27      2008     Massachusetts       CalPolySLO   5.5    -240
# 28      2008        NoIllinois     NorthernIowa    14   -1250
# 29      2008   WesternCarolina     BowlingGreen     1    -125
# ...      ...               ...              ...   ...     ...
# 44705   2019          Lipscomb          NCState     5    -230
# 44706   2019          Colorado            Texas     5    -220
# 44707   2019   CoastalCarolina           Depaul     8    -350
# 44708   2019            Purdue        Tennessee   1.5    -130
# 44709   2019            Oregon         Virginia   8.5    -440
# 44710   2019      FloridaState          Gonzaga   7.5    -425
# 44711   2019         TexasTech         Michigan     2    -140
# 44712   2019   LoyolaMarymount     SouthFlorida     4    -190
# 44713   2019           Hampton             NJIT   3.5    -170
# 44714   2019     TexasSouthern         ULMonroe     8    -400
# 44715   2019               LSU    MichiganState     6    -280
# 44716   2019      VirginiaTech             Duke   7.5    -450
# 44717   2019          HoustonU         Kentucky     2    -135
# 44718   2019            Auburn    NorthCarolina   5.5    -270
# 44719   2019     CSBakersfield     WiscGreenBay     6    -270
# 44720   2019            Purdue         Virginia   4.5    -225
# 44721   2019         TexasTech          Gonzaga     5    -255
# 44722   2019     MichiganState             Duke   2.5    -155
# 44723   2019            Auburn         Kentucky   4.5    -220
# 44724   2019            Depaul     SouthFlorida     1    -125
# 44725   2019      WichitaState         Lipscomb     1    -120
# 44727   2019           Hampton         Marshall     7    -300
# 44728   2019     TexasSouthern     WiscGreenBay     6    -260
# 44729   2019      SouthFlorida           Depaul   4.5    -240
# 44730   2019          Lipscomb            Texas   1.5    -125
# 44731   2019      WiscGreenBay         Marshall     5    -230
# 44732   2019      SouthFlorida           Depaul   1.5    -125
# 44733   2019         TexasTech    MichiganState     2    -140
# 44734   2019            Auburn         Virginia   6.5    -330
# 44735   2019         TexasTech         Virginia     2    -136
#
#               Favorite           Winner   MoV  Result
# 0             Richmond         Richmond   2.0       1
# 1             MemphisU         MemphisU  31.0       1
# 2          GardnerWebb      GardnerWebb  14.0       1
# 3             Kentucky         Kentucky  27.0       1
# 4           TennMartin       TennMartin   4.0       1
# 5             MemphisU         MemphisU  17.0       1
# 6              Buffalo          Buffalo   7.0       1
# 7      CentralArkansas  CentralArkansas  10.0       1
# 8             Kentucky      GardnerWebb -16.0       0
# 9          MorganState      MorganState  11.0       1
# 10         Connecticut      Connecticut  25.0       1
# 11             DenverU          DenverU   1.0       1
# 12            Oklahoma         Oklahoma  16.0       1
# 13                Ohio             Ohio   8.0       1
# 14             Fordham          Fordham  18.0       1
# 15              Drexel           Drexel   8.0       1
# 16              Butler           Butler  16.0       1
# 17         RhodeIsland      RhodeIsland  27.0       1
# 18        SouthFlorida   ClevelandState  -3.0       0
# 19     EasternMichigan            Brown -19.0       0
# 20           Tennessee        Tennessee  17.0       1
# 21           Creighton        Creighton  12.0       1
# 22             Alabama          Alabama  12.0       1
# 23           NewMexico        NewMexico   7.0       1
# 24              Tulane           Tulane  15.0       1
# 25           CalIrvine        CalIrvine  13.0       1
# 26              Hawaii         SanDiego  -1.0       0
# 27       Massachusetts    Massachusetts  26.0       1
# 28        NorthernIowa     NorthernIowa  30.0       1
# 29     WesternCarolina  WesternCarolina   3.0       1
# ...                ...              ...   ...     ...
# 44705          NCState         Lipscomb  -1.0       0
# 44706            Texas            Texas  13.0       1
# 44707           Depaul           Depaul   5.0       1
# 44708        Tennessee           Purdue  -5.0       0
# 44709         Virginia         Virginia   4.0       1
# 44710          Gonzaga          Gonzaga  14.0       1
# 44711         Michigan        TexasTech -19.0       0
# 44712     SouthFlorida     SouthFlorida   9.0       1
# 44713             NJIT          Hampton -12.0       0
# 44714         ULMonroe    TexasSouthern  -6.0       0
# 44715    MichiganState    MichiganState  17.0       1
# 44716             Duke             Duke   2.0       1
# 44717         Kentucky         Kentucky   4.0       1
# 44718    NorthCarolina           Auburn -17.0       0
# 44719     WiscGreenBay     WiscGreenBay  15.0       1
# 44720         Virginia         Virginia   5.0       1
# 44721          Gonzaga        TexasTech  -6.0       0
# 44722             Duke    MichiganState  -1.0       0
# 44723         Kentucky           Auburn  -6.0       0
# 44724     SouthFlorida     SouthFlorida   2.0       1
# 44725         Lipscomb         Lipscomb   7.0       1
# 44727         Marshall         Marshall   2.0       1
# 44728     WiscGreenBay     WiscGreenBay   1.0       1
# 44729           Depaul           Depaul   4.0       1
# 44730            Texas            Texas  15.0       1
# 44731         Marshall         Marshall  20.0       1
# 44732           Depaul     SouthFlorida -12.0       0
# 44733    MichiganState        TexasTech -10.0       0
# 44734         Virginia         Virginia   1.0       1
# 44735         Virginia         Virginia   8.0       1
#
# [44100 rows x 9 columns]

# %%
indexNames = df1[df1['MoV'].isnull()].index.tolist()

df1.drop(indexNames,inplace=True)

indexes = df1[df1['Line']>100].index

df1.drop(indexes,inplace=True)

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

x = pd.DataFrame(df1['Line'])
y = pd.DataFrame(df1['MoV'])


model = LinearRegression()

model.fit(x,y)

r_sq = model.score(x,y)
print('coefficient of determination: ' + str(r_sq))
# Out:
# coefficient of determination: 0.2278588787933925

# %%
plt.scatter(x,y)
plt.show()

# %%
import math

df['diff']=df1['MoV']-df1['Line']

data = df['diff']

w=400
n=math.ceil((data.max())-data.min()/w)

df['diff'].hist(bins=n)

print(np.std(data))
print(np.std(df1['MoV']))
print(np.std(df1['Line']))
# Out:
# 10.49775428685966
# 12.142119528557021
# 5.506108616872981

# %%
df1 = df1.drop(['Season','Team1','Team2','ML','Favorite','Winner'],axis=1)

df_win = df1

indexW = df_win[df_win['Result']==1].index
indexL = df_win[df_win['Result']==0].index

df_lose = df_win.copy()
df_lose['Line'] = df_lose['Line']*-1
df_lose.loc[indexW,'Result'] = 0
df_lose.loc[indexL,'Result'] = 1



df_lose
# Out:
#        Line   MoV  Result
# 0      -5.5   2.0       0
# 1     -35.5  31.0       0
# 2        -3  14.0       0
# 3     -26.5  27.0       0
# 4      -1.5   4.0       0
# 5     -29.5  17.0       0
# 6       -25   7.0       0
# 7      -3.5  10.0       0
# 8     -26.5 -16.0       1
# 9     -11.5  11.0       0
# 10      -19  25.0       0
# 11     -8.5   1.0       0
# 12    -17.5  16.0       0
# 13     -3.5   8.0       0
# 14       -5  18.0       0
# 15       -3   8.0       0
# 16    -10.5  16.0       0
# 17      -13  27.0       0
# 18     -7.5  -3.0       1
# 19     -5.5 -19.0       1
# 20    -17.5  17.0       0
# 21       -3  12.0       0
# 22      -17  12.0       0
# 23       -1   7.0       0
# 24     -2.5  15.0       0
# 25     -9.5  13.0       0
# 26     -8.5  -1.0       1
# 27     -5.5  26.0       0
# 28      -14  30.0       0
# 29       -1   3.0       0
# ...     ...   ...     ...
# 44705    -5  -1.0       1
# 44706    -5  13.0       0
# 44707    -8   5.0       0
# 44708  -1.5  -5.0       1
# 44709  -8.5   4.0       0
# 44710  -7.5  14.0       0
# 44711    -2 -19.0       1
# 44712    -4   9.0       0
# 44713  -3.5 -12.0       1
# 44714    -8  -6.0       1
# 44715    -6  17.0       0
# 44716  -7.5   2.0       0
# 44717    -2   4.0       0
# 44718  -5.5 -17.0       1
# 44719    -6  15.0       0
# 44720  -4.5   5.0       0
# 44721    -5  -6.0       1
# 44722  -2.5  -1.0       1
# 44723  -4.5  -6.0       1
# 44724    -1   2.0       0
# 44725    -1   7.0       0
# 44727    -7   2.0       0
# 44728    -6   1.0       0
# 44729  -4.5   4.0       0
# 44730  -1.5  15.0       0
# 44731    -5  20.0       0
# 44732  -1.5 -12.0       1
# 44733    -2 -10.0       1
# 44734  -6.5   1.0       0
# 44735    -2   8.0       0
#
# [44097 rows x 3 columns]

# %%
df_final = pd.concat((df_win,df_lose)).reset_index(drop=True)

df_final
# Out:
#        Line   MoV  Result
# 0       5.5   2.0       1
# 1      35.5  31.0       1
# 2         3  14.0       1
# 3      26.5  27.0       1
# 4       1.5   4.0       1
# 5      29.5  17.0       1
# 6        25   7.0       1
# 7       3.5  10.0       1
# 8      26.5 -16.0       0
# 9      11.5  11.0       1
# 10       19  25.0       1
# 11      8.5   1.0       1
# 12     17.5  16.0       1
# 13      3.5   8.0       1
# 14        5  18.0       1
# 15        3   8.0       1
# 16     10.5  16.0       1
# 17       13  27.0       1
# 18      7.5  -3.0       0
# 19      5.5 -19.0       0
# 20     17.5  17.0       1
# 21        3  12.0       1
# 22       17  12.0       1
# 23        1   7.0       1
# 24      2.5  15.0       1
# 25      9.5  13.0       1
# 26      8.5  -1.0       0
# 27      5.5  26.0       1
# 28       14  30.0       1
# 29        1   3.0       1
# ...     ...   ...     ...
# 88164    -5  -1.0       1
# 88165    -5  13.0       0
# 88166    -8   5.0       0
# 88167  -1.5  -5.0       1
# 88168  -8.5   4.0       0
# 88169  -7.5  14.0       0
# 88170    -2 -19.0       1
# 88171    -4   9.0       0
# 88172  -3.5 -12.0       1
# 88173    -8  -6.0       1
# 88174    -6  17.0       0
# 88175  -7.5   2.0       0
# 88176    -2   4.0       0
# 88177  -5.5 -17.0       1
# 88178    -6  15.0       0
# 88179  -4.5   5.0       0
# 88180    -5  -6.0       1
# 88181  -2.5  -1.0       1
# 88182  -4.5  -6.0       1
# 88183    -1   2.0       0
# 88184    -1   7.0       0
# 88185    -7   2.0       0
# 88186    -6   1.0       0
# 88187  -4.5   4.0       0
# 88188  -1.5  15.0       0
# 88189    -5  20.0       0
# 88190  -1.5 -12.0       1
# 88191    -2 -10.0       1
# 88192  -6.5   1.0       0
# 88193    -2   8.0       0
#
# [88194 rows x 3 columns]

# %%
feature_cols=['Line']
X = df_final[feature_cols]
y= df_final.Result

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_test,y_pred)
cnf_matrix
# Out:
# array([[8267, 2829],
#        [2901, 8052]], dtype=int64)

# %%
print('Accuracy:',metrics.accuracy_score(y_test, y_pred))
print('Precision:',metrics.precision_score(y_test, y_pred))
print('Recall:',metrics.recall_score(y_test, y_pred))
print('Log-Loss:',metrics.log_loss(y_test,y_pred))
# Out:
# Accuracy: 0.7401242686743162
# Precision: 0.7400055141990626
# Recall: 0.7351410572445906
# Log-Loss: 8.975892367180744

# %%
y_pred_proba = logreg.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label='data 1, auc='+str(auc))
plt.legend(loc=4)
plt.show()
